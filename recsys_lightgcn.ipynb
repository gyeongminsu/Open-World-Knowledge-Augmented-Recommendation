# %%
import os

# !nvidia-smi
# Out:
# Wed Dec  4 16:07:13 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.02              Driver Version: 555.42.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               On  |   00000000:4F:00.0 Off |                  Off |
# | 30%   29C    P8             25W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000               On  |   00000000:52:00.0 Off |                  Off |
# | 30%   31C    P8             19W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA RTX A6000               On  |   00000000:56:00.0 Off |                  Off |
# | 30%   28C    P8             24W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA RTX A6000               On  |   00000000:57:00.0 Off |                  Off |
# | 30%   31C    P8             22W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Reranking

# %%
os.chdir("/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS")
# !python run_rerank_LightGCN.py
# Out:
# ---------------bs,lr,wd,epoch, export share/spcf, convert arch ---------- 256 5e-4 50 0 2 5 128,32 LightGCN
# max hist len 5
# 202412041650
# parameters Namespace(data_dir='../data/amz/proc_data', save_dir='./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True', reload_path='', setting_path='', device='cuda', seed=1234, output_dim=1, timestamp='202412041650', epoch_num=50, batch_size=256, lr=0.0005, weight_decay=0.0, adam_betas='0.9,0.999', adam_epsilon=1e-08, lr_sched='cosine', warmup_ratio=0.0, dropout=0.0, convert_dropout=0.0, grad_norm=0, test=False, patience=3, metric_scope=[1, 3, 5, 7], task='rerank', algo='LightGCN', augment=True, aug_prefix='bert_avg', convert_type='HEA', max_hist_len=5, embed_dim=32, final_mlp_arch=[200, 80], convert_arch=[128, 32], export_num=2, top_expt_num=4, specific_export_num=5, auxi_loss_weight=0, hidden_size=64, rnn_dp=0.0, n_head=2, ff_dim=128, attn_dp=0.0, temperature=0.5, n_layers=4, max_depth=6, n_estimators=100, feature_mlp_arch=[256, 128, 64], llm_heads=4, llm_layers=2, llm_ff_dim=256, norm_scale=1.0, layer_weight_init=1.0, neighbor_weight_init=1.0)
# Train data size: 320368 Test data size: 35834
# HEA
# convert module: HEA
# metric scope [1, 3, 5, 7]
# test loss: 2.36551, test time: 33.10993
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36898, NDCG: 0.27010, CLICK: 0.71795
# @5, MAP: 0.39297, NDCG: 0.34451, CLICK: 1.19066
# @7, MAP: 0.38944, NDCG: 0.42478, CLICK: 1.66515
# /gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/optimization.py:139: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1581.)
#   exp_avg.mul_(beta1).add_(-beta1 + 1.0, grad)
# epoch: 0, train time: 306.16886, test loss: 0.73814, test time: 33.65255
# @1, MAP: 0.24248, NDCG: 0.24248, CLICK: 0.24248
# @3, MAP: 0.37104, NDCG: 0.27029, CLICK: 0.71697
# @5, MAP: 0.39422, NDCG: 0.34547, CLICK: 1.19532
# @7, MAP: 0.39025, NDCG: 0.42665, CLICK: 1.67665
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 1, train time: 305.29717, test loss: 0.66637, test time: 33.67405
# @1, MAP: 0.24248, NDCG: 0.24248, CLICK: 0.24248
# @3, MAP: 0.37084, NDCG: 0.27039, CLICK: 0.71837
# @5, MAP: 0.39423, NDCG: 0.34492, CLICK: 1.19163
# @7, MAP: 0.39009, NDCG: 0.42547, CLICK: 1.66710
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 2, train time: 305.93394, test loss: 0.62886, test time: 33.71099
# @1, MAP: 0.24025, NDCG: 0.24025, CLICK: 0.24025
# @3, MAP: 0.37115, NDCG: 0.27017, CLICK: 0.71714
# @5, MAP: 0.39358, NDCG: 0.34497, CLICK: 1.19163
# @7, MAP: 0.39009, NDCG: 0.42552, CLICK: 1.66710
# epoch: 3, train time: 305.33742, test loss: 0.58538, test time: 33.61573
# @1, MAP: 0.24025, NDCG: 0.24025, CLICK: 0.24025
# @3, MAP: 0.36914, NDCG: 0.26914, CLICK: 0.71351
# @5, MAP: 0.39254, NDCG: 0.34448, CLICK: 1.19163
# @7, MAP: 0.38930, NDCG: 0.42569, CLICK: 1.67190
# epoch: 4, train time: 305.92729, test loss: 0.55705, test time: 34.39947
# @1, MAP: 0.24025, NDCG: 0.24025, CLICK: 0.24025
# @3, MAP: 0.36780, NDCG: 0.26801, CLICK: 0.71030
# @5, MAP: 0.39214, NDCG: 0.34425, CLICK: 1.19163
# @7, MAP: 0.38895, NDCG: 0.42546, CLICK: 1.67190
# ---------------bs,lr,wd,epoch, export share/spcf, convert arch ---------- 256 5e-4 50 0 3 4 128,32 LightGCN
# max hist len 5
# 202412041719
# parameters Namespace(data_dir='../data/amz/proc_data', save_dir='./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd0_drop0.0_hl200,80_cl3_augment_True', reload_path='', setting_path='', device='cuda', seed=1234, output_dim=1, timestamp='202412041719', epoch_num=50, batch_size=256, lr=0.0005, weight_decay=0.0, adam_betas='0.9,0.999', adam_epsilon=1e-08, lr_sched='cosine', warmup_ratio=0.0, dropout=0.0, convert_dropout=0.0, grad_norm=0, test=False, patience=3, metric_scope=[1, 3, 5, 7], task='rerank', algo='LightGCN', augment=True, aug_prefix='bert_avg', convert_type='HEA', max_hist_len=5, embed_dim=32, final_mlp_arch=[200, 80], convert_arch=[128, 32], export_num=3, top_expt_num=4, specific_export_num=4, auxi_loss_weight=0, hidden_size=64, rnn_dp=0.0, n_head=2, ff_dim=128, attn_dp=0.0, temperature=0.5, n_layers=4, max_depth=6, n_estimators=100, feature_mlp_arch=[256, 128, 64], llm_heads=4, llm_layers=2, llm_ff_dim=256, norm_scale=1.0, layer_weight_init=1.0, neighbor_weight_init=1.0)
# Train data size: 320368 Test data size: 35834
# HEA
# convert module: HEA
# metric scope [1, 3, 5, 7]
# test loss: 2.31060, test time: 33.77416
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36898, NDCG: 0.27010, CLICK: 0.71795
# @5, MAP: 0.39297, NDCG: 0.34451, CLICK: 1.19066
# @7, MAP: 0.38944, NDCG: 0.42478, CLICK: 1.66515
# /gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/optimization.py:139: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1581.)
#   exp_avg.mul_(beta1).add_(-beta1 + 1.0, grad)
# epoch: 0, train time: 304.15466, test loss: 0.72791, test time: 33.60212
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36760, NDCG: 0.26848, CLICK: 0.71474
# @5, MAP: 0.39218, NDCG: 0.34401, CLICK: 1.19308
# @7, MAP: 0.38862, NDCG: 0.42523, CLICK: 1.67442
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 1, train time: 304.85583, test loss: 0.66191, test time: 33.72217
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36676, NDCG: 0.26834, CLICK: 0.71594
# @5, MAP: 0.39251, NDCG: 0.34392, CLICK: 1.19306
# @7, MAP: 0.38884, NDCG: 0.42381, CLICK: 1.66576
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 2, train time: 305.09672, test loss: 0.61694, test time: 33.69251
# @1, MAP: 0.23827, NDCG: 0.23827, CLICK: 0.23827
# @3, MAP: 0.36867, NDCG: 0.26842, CLICK: 0.71396
# @5, MAP: 0.39180, NDCG: 0.34350, CLICK: 1.19144
# @7, MAP: 0.38808, NDCG: 0.42485, CLICK: 1.67416
# epoch: 3, train time: 304.79779, test loss: 0.57297, test time: 33.58019
# @1, MAP: 0.23827, NDCG: 0.23827, CLICK: 0.23827
# @3, MAP: 0.36758, NDCG: 0.26811, CLICK: 0.71273
# @5, MAP: 0.39184, NDCG: 0.34341, CLICK: 1.19144
# @7, MAP: 0.38827, NDCG: 0.42473, CLICK: 1.67277
# epoch: 4, train time: 305.41976, test loss: 0.55292, test time: 32.88511
# @1, MAP: 0.23827, NDCG: 0.23827, CLICK: 0.23827
# @3, MAP: 0.37023, NDCG: 0.26944, CLICK: 0.71574
# @5, MAP: 0.39306, NDCG: 0.34510, CLICK: 1.19465
# @7, MAP: 0.38950, NDCG: 0.42559, CLICK: 1.67277
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 5, train time: 304.53989, test loss: 0.54981, test time: 33.28510
# @1, MAP: 0.23441, NDCG: 0.23441, CLICK: 0.23441
# @3, MAP: 0.36783, NDCG: 0.26861, CLICK: 0.71753
# @5, MAP: 0.39066, NDCG: 0.34354, CLICK: 1.19342
# @7, MAP: 0.38758, NDCG: 0.42456, CLICK: 1.67416
# epoch: 6, train time: 304.38642, test loss: 0.54975, test time: 33.32679
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36674, NDCG: 0.26891, CLICK: 0.71876
# @5, MAP: 0.39186, NDCG: 0.34503, CLICK: 1.20009
# @7, MAP: 0.38832, NDCG: 0.42590, CLICK: 1.67754
# epoch: 7, train time: 303.19168, test loss: 0.54977, test time: 33.33509
# @1, MAP: 0.24025, NDCG: 0.24025, CLICK: 0.24025
# @3, MAP: 0.37138, NDCG: 0.27025, CLICK: 0.71750
# @5, MAP: 0.39472, NDCG: 0.34618, CLICK: 1.19828
# @7, MAP: 0.39054, NDCG: 0.42629, CLICK: 1.67154
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 8, train time: 302.92713, test loss: 0.54976, test time: 32.83882
# @1, MAP: 0.24248, NDCG: 0.24248, CLICK: 0.24248
# @3, MAP: 0.37252, NDCG: 0.27169, CLICK: 0.72138
# @5, MAP: 0.39524, NDCG: 0.34600, CLICK: 1.19532
# @7, MAP: 0.39065, NDCG: 0.42686, CLICK: 1.67277
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 9, train time: 302.15549, test loss: 0.54976, test time: 33.26424
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36544, NDCG: 0.26723, CLICK: 0.71312
# @5, MAP: 0.38991, NDCG: 0.34298, CLICK: 1.19166
# @7, MAP: 0.38699, NDCG: 0.42403, CLICK: 1.67241
# epoch: 10, train time: 301.70312, test loss: 0.54976, test time: 33.36512
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36981, NDCG: 0.26977, CLICK: 0.71750
# @5, MAP: 0.39352, NDCG: 0.34591, CLICK: 1.19883
# @7, MAP: 0.38968, NDCG: 0.42623, CLICK: 1.67573
# epoch: 11, train time: 302.58581, test loss: 0.54975, test time: 33.36717
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36744, NDCG: 0.26913, CLICK: 0.71837
# @5, MAP: 0.39165, NDCG: 0.34441, CLICK: 1.19671
# @7, MAP: 0.38803, NDCG: 0.42567, CLICK: 1.67698
# ---------------bs,lr,wd,epoch, export share/spcf, convert arch ---------- 256 5e-4 50 0 2 6 128,32 LightGCN
# max hist len 5
# 202412041828
# parameters Namespace(data_dir='../data/amz/proc_data', save_dir='./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True', reload_path='', setting_path='', device='cuda', seed=1234, output_dim=1, timestamp='202412041828', epoch_num=50, batch_size=256, lr=0.0005, weight_decay=0.0, adam_betas='0.9,0.999', adam_epsilon=1e-08, lr_sched='cosine', warmup_ratio=0.0, dropout=0.0, convert_dropout=0.0, grad_norm=0, test=False, patience=3, metric_scope=[1, 3, 5, 7], task='rerank', algo='LightGCN', augment=True, aug_prefix='bert_avg', convert_type='HEA', max_hist_len=5, embed_dim=32, final_mlp_arch=[200, 80], convert_arch=[128, 32], export_num=2, top_expt_num=4, specific_export_num=6, auxi_loss_weight=0, hidden_size=64, rnn_dp=0.0, n_head=2, ff_dim=128, attn_dp=0.0, temperature=0.5, n_layers=4, max_depth=6, n_estimators=100, feature_mlp_arch=[256, 128, 64], llm_heads=4, llm_layers=2, llm_ff_dim=256, norm_scale=1.0, layer_weight_init=1.0, neighbor_weight_init=1.0)
# Train data size: 320368 Test data size: 35834
# HEA
# convert module: HEA
# metric scope [1, 3, 5, 7]
# test loss: 1.85375, test time: 33.12022
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36898, NDCG: 0.27010, CLICK: 0.71795
# @5, MAP: 0.39297, NDCG: 0.34451, CLICK: 1.19066
# @7, MAP: 0.38944, NDCG: 0.42478, CLICK: 1.66515
# /gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/optimization.py:139: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1581.)
#   exp_avg.mul_(beta1).add_(-beta1 + 1.0, grad)
# epoch: 0, train time: 306.96366, test loss: 0.70314, test time: 33.54503
# @1, MAP: 0.23829, NDCG: 0.23829, CLICK: 0.23829
# @3, MAP: 0.36912, NDCG: 0.26863, CLICK: 0.71156
# @5, MAP: 0.39280, NDCG: 0.34534, CLICK: 1.19710
# @7, MAP: 0.38938, NDCG: 0.42620, CLICK: 1.67455
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 1, train time: 305.77944, test loss: 0.65711, test time: 33.61157
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36888, NDCG: 0.26926, CLICK: 0.71555
# @5, MAP: 0.39283, NDCG: 0.34476, CLICK: 1.19303
# @7, MAP: 0.38943, NDCG: 0.42503, CLICK: 1.66752
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 2, train time: 306.46704, test loss: 0.61848, test time: 33.64538
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36888, NDCG: 0.26926, CLICK: 0.71555
# @5, MAP: 0.39301, NDCG: 0.34494, CLICK: 1.19426
# @7, MAP: 0.38948, NDCG: 0.42504, CLICK: 1.66752
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 3, train time: 305.79597, test loss: 0.57480, test time: 33.78171
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36917, NDCG: 0.26932, CLICK: 0.71555
# @5, MAP: 0.39310, NDCG: 0.34499, CLICK: 1.19426
# @7, MAP: 0.38972, NDCG: 0.42516, CLICK: 1.66752
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 4, train time: 306.61312, test loss: 0.55314, test time: 33.83486
# @1, MAP: 0.24005, NDCG: 0.24005, CLICK: 0.24005
# @3, MAP: 0.36988, NDCG: 0.26959, CLICK: 0.71555
# @5, MAP: 0.39308, NDCG: 0.34513, CLICK: 1.19426
# @7, MAP: 0.38979, NDCG: 0.42626, CLICK: 1.67335
# epoch: 5, train time: 306.05511, test loss: 0.54981, test time: 33.99014
# @1, MAP: 0.24005, NDCG: 0.24005, CLICK: 0.24005
# @3, MAP: 0.37021, NDCG: 0.27020, CLICK: 0.71859
# @5, MAP: 0.39371, NDCG: 0.34536, CLICK: 1.19607
# @7, MAP: 0.39019, NDCG: 0.42668, CLICK: 1.67740
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 6, train time: 306.40778, test loss: 0.54976, test time: 33.87225
# @1, MAP: 0.23829, NDCG: 0.23829, CLICK: 0.23829
# @3, MAP: 0.36973, NDCG: 0.26957, CLICK: 0.71574
# @5, MAP: 0.39335, NDCG: 0.34348, CLICK: 1.18580
# @7, MAP: 0.38905, NDCG: 0.42415, CLICK: 1.66412
# epoch: 7, train time: 307.63648, test loss: 0.54976, test time: 33.74234
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36754, NDCG: 0.26743, CLICK: 0.71114
# @5, MAP: 0.39204, NDCG: 0.34344, CLICK: 1.19004
# @7, MAP: 0.38732, NDCG: 0.42516, CLICK: 1.67559
# epoch: 8, train time: 307.53185, test loss: 0.54976, test time: 33.72777
# @1, MAP: 0.24005, NDCG: 0.24005, CLICK: 0.24005
# @3, MAP: 0.37073, NDCG: 0.27000, CLICK: 0.71817
# @5, MAP: 0.39429, NDCG: 0.34609, CLICK: 1.20009
# @7, MAP: 0.39011, NDCG: 0.42593, CLICK: 1.67280
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 9, train time: 307.07202, test loss: 0.54976, test time: 33.61311
# @1, MAP: 0.24025, NDCG: 0.24025, CLICK: 0.24025
# @3, MAP: 0.36898, NDCG: 0.26910, CLICK: 0.71415
# @5, MAP: 0.39325, NDCG: 0.34515, CLICK: 1.19551
# @7, MAP: 0.38929, NDCG: 0.42633, CLICK: 1.67804
# epoch: 10, train time: 307.14028, test loss: 0.54974, test time: 33.68427
# @1, MAP: 0.24307, NDCG: 0.24307, CLICK: 0.24307
# @3, MAP: 0.37352, NDCG: 0.27262, CLICK: 0.72440
# @5, MAP: 0.39602, NDCG: 0.34718, CLICK: 1.20009
# @7, MAP: 0.39174, NDCG: 0.42803, CLICK: 1.67863
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd0_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 11, train time: 307.80100, test loss: 0.54976, test time: 34.05184
# @1, MAP: 0.23885, NDCG: 0.23885, CLICK: 0.23885
# @3, MAP: 0.37033, NDCG: 0.26919, CLICK: 0.71332
# @5, MAP: 0.39383, NDCG: 0.34567, CLICK: 1.19663
# @7, MAP: 0.39026, NDCG: 0.42569, CLICK: 1.66948
# epoch: 12, train time: 307.21367, test loss: 0.54976, test time: 33.94927
# @1, MAP: 0.24005, NDCG: 0.24005, CLICK: 0.24005
# @3, MAP: 0.37179, NDCG: 0.27067, CLICK: 0.71915
# @5, MAP: 0.39453, NDCG: 0.34570, CLICK: 1.19663
# @7, MAP: 0.38985, NDCG: 0.42623, CLICK: 1.67319
# epoch: 13, train time: 307.89549, test loss: 0.54975, test time: 33.49566
# @1, MAP: 0.23885, NDCG: 0.23885, CLICK: 0.23885
# @3, MAP: 0.37141, NDCG: 0.27114, CLICK: 0.71912
# @5, MAP: 0.39464, NDCG: 0.34664, CLICK: 1.19744
# @7, MAP: 0.39030, NDCG: 0.42800, CLICK: 1.68016
# ---------------bs,lr,wd,epoch, export share/spcf, convert arch ---------- 256 5e-4 50 1e-4 2 5 128,32 LightGCN
# max hist len 5
# 202412041948
# parameters Namespace(data_dir='../data/amz/proc_data', save_dir='./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd1e-4_drop0.0_hl200,80_cl3_augment_True', reload_path='', setting_path='', device='cuda', seed=1234, output_dim=1, timestamp='202412041948', epoch_num=50, batch_size=256, lr=0.0005, weight_decay=0.0001, adam_betas='0.9,0.999', adam_epsilon=1e-08, lr_sched='cosine', warmup_ratio=0.0, dropout=0.0, convert_dropout=0.0, grad_norm=0, test=False, patience=3, metric_scope=[1, 3, 5, 7], task='rerank', algo='LightGCN', augment=True, aug_prefix='bert_avg', convert_type='HEA', max_hist_len=5, embed_dim=32, final_mlp_arch=[200, 80], convert_arch=[128, 32], export_num=2, top_expt_num=4, specific_export_num=5, auxi_loss_weight=0, hidden_size=64, rnn_dp=0.0, n_head=2, ff_dim=128, attn_dp=0.0, temperature=0.5, n_layers=4, max_depth=6, n_estimators=100, feature_mlp_arch=[256, 128, 64], llm_heads=4, llm_layers=2, llm_ff_dim=256, norm_scale=1.0, layer_weight_init=1.0, neighbor_weight_init=1.0)
# Train data size: 320368 Test data size: 35834
# HEA
# convert module: HEA
# metric scope [1, 3, 5, 7]
# test loss: 2.36551, test time: 33.02254
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36898, NDCG: 0.27010, CLICK: 0.71795
# @5, MAP: 0.39297, NDCG: 0.34451, CLICK: 1.19066
# @7, MAP: 0.38944, NDCG: 0.42478, CLICK: 1.66515
# /gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/optimization.py:139: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1581.)
#   exp_avg.mul_(beta1).add_(-beta1 + 1.0, grad)
# epoch: 0, train time: 304.90024, test loss: 0.73814, test time: 33.58821
# @1, MAP: 0.24248, NDCG: 0.24248, CLICK: 0.24248
# @3, MAP: 0.37104, NDCG: 0.27029, CLICK: 0.71697
# @5, MAP: 0.39422, NDCG: 0.34547, CLICK: 1.19532
# @7, MAP: 0.39025, NDCG: 0.42665, CLICK: 1.67665
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd1e-4_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 1, train time: 304.69041, test loss: 0.66637, test time: 33.72646
# @1, MAP: 0.24248, NDCG: 0.24248, CLICK: 0.24248
# @3, MAP: 0.37084, NDCG: 0.27039, CLICK: 0.71837
# @5, MAP: 0.39423, NDCG: 0.34492, CLICK: 1.19163
# @7, MAP: 0.39009, NDCG: 0.42547, CLICK: 1.66710
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_2_wd1e-4_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 2, train time: 305.32559, test loss: 0.62887, test time: 33.77685
# @1, MAP: 0.24025, NDCG: 0.24025, CLICK: 0.24025
# @3, MAP: 0.37115, NDCG: 0.27017, CLICK: 0.71714
# @5, MAP: 0.39358, NDCG: 0.34497, CLICK: 1.19163
# @7, MAP: 0.39009, NDCG: 0.42552, CLICK: 1.66710
# epoch: 3, train time: 304.17384, test loss: 0.58540, test time: 33.49579
# @1, MAP: 0.24025, NDCG: 0.24025, CLICK: 0.24025
# @3, MAP: 0.36914, NDCG: 0.26914, CLICK: 0.71351
# @5, MAP: 0.39254, NDCG: 0.34448, CLICK: 1.19163
# @7, MAP: 0.38930, NDCG: 0.42569, CLICK: 1.67190
# epoch: 4, train time: 304.16358, test loss: 0.55706, test time: 34.21309
# @1, MAP: 0.24025, NDCG: 0.24025, CLICK: 0.24025
# @3, MAP: 0.36780, NDCG: 0.26801, CLICK: 0.71030
# @5, MAP: 0.39214, NDCG: 0.34425, CLICK: 1.19163
# @7, MAP: 0.38895, NDCG: 0.42546, CLICK: 1.67190
# ---------------bs,lr,wd,epoch, export share/spcf, convert arch ---------- 256 5e-4 50 1e-4 3 4 128,32 LightGCN
# max hist len 5
# 202412042017
# parameters Namespace(data_dir='../data/amz/proc_data', save_dir='./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd1e-4_drop0.0_hl200,80_cl3_augment_True', reload_path='', setting_path='', device='cuda', seed=1234, output_dim=1, timestamp='202412042017', epoch_num=50, batch_size=256, lr=0.0005, weight_decay=0.0001, adam_betas='0.9,0.999', adam_epsilon=1e-08, lr_sched='cosine', warmup_ratio=0.0, dropout=0.0, convert_dropout=0.0, grad_norm=0, test=False, patience=3, metric_scope=[1, 3, 5, 7], task='rerank', algo='LightGCN', augment=True, aug_prefix='bert_avg', convert_type='HEA', max_hist_len=5, embed_dim=32, final_mlp_arch=[200, 80], convert_arch=[128, 32], export_num=3, top_expt_num=4, specific_export_num=4, auxi_loss_weight=0, hidden_size=64, rnn_dp=0.0, n_head=2, ff_dim=128, attn_dp=0.0, temperature=0.5, n_layers=4, max_depth=6, n_estimators=100, feature_mlp_arch=[256, 128, 64], llm_heads=4, llm_layers=2, llm_ff_dim=256, norm_scale=1.0, layer_weight_init=1.0, neighbor_weight_init=1.0)
# Train data size: 320368 Test data size: 35834
# HEA
# convert module: HEA
# metric scope [1, 3, 5, 7]
# test loss: 2.31060, test time: 34.14682
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36898, NDCG: 0.27010, CLICK: 0.71795
# @5, MAP: 0.39297, NDCG: 0.34451, CLICK: 1.19066
# @7, MAP: 0.38944, NDCG: 0.42478, CLICK: 1.66515
# /gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/optimization.py:139: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1581.)
#   exp_avg.mul_(beta1).add_(-beta1 + 1.0, grad)
# epoch: 0, train time: 306.04746, test loss: 0.72791, test time: 33.81130
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36760, NDCG: 0.26848, CLICK: 0.71474
# @5, MAP: 0.39218, NDCG: 0.34401, CLICK: 1.19308
# @7, MAP: 0.38862, NDCG: 0.42523, CLICK: 1.67442
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd1e-4_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 1, train time: 306.02506, test loss: 0.66192, test time: 33.90059
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36676, NDCG: 0.26834, CLICK: 0.71594
# @5, MAP: 0.39251, NDCG: 0.34392, CLICK: 1.19306
# @7, MAP: 0.38884, NDCG: 0.42381, CLICK: 1.66576
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd1e-4_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 2, train time: 306.66354, test loss: 0.61695, test time: 33.90316
# @1, MAP: 0.23827, NDCG: 0.23827, CLICK: 0.23827
# @3, MAP: 0.36867, NDCG: 0.26842, CLICK: 0.71396
# @5, MAP: 0.39180, NDCG: 0.34350, CLICK: 1.19144
# @7, MAP: 0.38808, NDCG: 0.42485, CLICK: 1.67416
# epoch: 3, train time: 306.02865, test loss: 0.57298, test time: 33.88406
# @1, MAP: 0.23827, NDCG: 0.23827, CLICK: 0.23827
# @3, MAP: 0.36758, NDCG: 0.26811, CLICK: 0.71273
# @5, MAP: 0.39184, NDCG: 0.34341, CLICK: 1.19144
# @7, MAP: 0.38827, NDCG: 0.42473, CLICK: 1.67277
# epoch: 4, train time: 306.74437, test loss: 0.55293, test time: 33.09371
# @1, MAP: 0.23827, NDCG: 0.23827, CLICK: 0.23827
# @3, MAP: 0.37023, NDCG: 0.26944, CLICK: 0.71574
# @5, MAP: 0.39306, NDCG: 0.34510, CLICK: 1.19465
# @7, MAP: 0.38950, NDCG: 0.42559, CLICK: 1.67277
# model save in ./model/amz/rerank/LightGCN/WDA_Emb32_epoch50_bs256_lr5e-4_cosine_cnvt_arch_128,32_cnvt_type_HEA_eprt_3_wd1e-4_drop0.0_hl200,80_cl3_augment_True/LightGCN.pt
# epoch: 5, train time: 306.73583, test loss: 0.54981, test time: 33.86230
# @1, MAP: 0.23441, NDCG: 0.23441, CLICK: 0.23441
# @3, MAP: 0.36783, NDCG: 0.26861, CLICK: 0.71753
# @5, MAP: 0.39066, NDCG: 0.34354, CLICK: 1.19342
# @7, MAP: 0.38758, NDCG: 0.42456, CLICK: 1.67416
# epoch: 6, train time: 306.76342, test loss: 0.54975, test time: 33.81122
# @1, MAP: 0.23564, NDCG: 0.23564, CLICK: 0.23564
# @3, MAP: 0.36674, NDCG: 0.26891, CLICK: 0.71876
# @5, MAP: 0.39186, NDCG: 0.34503, CLICK: 1.20009
# @7, MAP: 0.38832, NDCG: 0.42590, CLICK: 1.67754
