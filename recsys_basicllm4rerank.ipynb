# %%
import os

# !nvidia-smi
# Out:
# Thu Dec  5 20:58:01 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.02              Driver Version: 555.42.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               On  |   00000000:4F:00.0 Off |                  Off |
# | 30%   29C    P8             24W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000               On  |   00000000:52:00.0 Off |                  Off |
# | 30%   31C    P8             19W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA RTX A6000               On  |   00000000:56:00.0 Off |                  Off |
# | 30%   28C    P8             23W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA RTX A6000               On  |   00000000:57:00.0 Off |                  Off |
# | 30%   31C    P8             22W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Reranking

# %%
os.chdir("/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS")
# !python run_basicllm4rerank.py
# Out:
# === Running experiments for BasicLLM4Rerank ===
# Testing with bs=256, lr=5e-4, wd=0
# max hist len 5
# 202412052100
# parameters Namespace(data_dir='../data/amz/proc_data', save_dir='./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd0', reload_path='', setting_path='', device='cuda', seed=1234, output_dim=1, timestamp='202412052100', epoch_num=50, batch_size=256, lr=0.0005, weight_decay=0.0, adam_betas='0.9,0.999', adam_epsilon=1e-08, lr_sched='cosine', warmup_ratio=0.0, dropout=0.0, convert_dropout=0.0, grad_norm=0, test=False, patience=3, metric_scope=[1, 3, 5, 7], task='rerank', algo='BasicLLM4Rerank', augment=False, aug_prefix='', convert_type='HEA', max_hist_len=5, embed_dim=32, final_mlp_arch=[200, 80], convert_arch=[128, 32], export_num=2, top_expt_num=4, specific_export_num=6, auxi_loss_weight=0, hidden_size=64, rnn_dp=0.0, n_head=2, ff_dim=128, attn_dp=0.0, temperature=1.0, n_layers=3, max_depth=6, n_estimators=100, feature_mlp_arch=[256, 128, 64], llm_heads=8, llm_layers=6, llm_ff_dim=512, norm_scale=1.0, layer_weight_init=1.0, neighbor_weight_init=1.0)
# Train data size: 320368 Test data size: 35834
# metric scope [1, 3, 5, 7]
# test loss: 0.72100, test time: 1.76687
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36898, NDCG: 0.27010, CLICK: 0.71795
# @5, MAP: 0.39297, NDCG: 0.34451, CLICK: 1.19066
# @7, MAP: 0.38944, NDCG: 0.42478, CLICK: 1.66515
# /gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/optimization.py:139: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1581.)
#   exp_avg.mul_(beta1).add_(-beta1 + 1.0, grad)
# epoch: 0, train time: 21.71810, test loss: 0.43062, test time: 1.89840
# @1, MAP: 0.52668, NDCG: 0.52668, CLICK: 0.52668
# @3, MAP: 0.62035, NDCG: 0.55190, CLICK: 1.41776
# @5, MAP: 0.61573, NDCG: 0.62717, CLICK: 1.99740
# @7, MAP: 0.60674, NDCG: 0.67151, CLICK: 2.25654
# model save in ./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd0/BasicLLM4Rerank.pt
# epoch: 1, train time: 21.54702, test loss: 0.39740, test time: 1.62836
# @1, MAP: 0.56583, NDCG: 0.56583, CLICK: 0.56583
# @3, MAP: 0.65223, NDCG: 0.59552, CLICK: 1.53368
# @5, MAP: 0.64637, NDCG: 0.66825, CLICK: 2.11347
# @7, MAP: 0.63941, NDCG: 0.70073, CLICK: 2.30223
# model save in ./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd0/BasicLLM4Rerank.pt
# epoch: 2, train time: 21.89860, test loss: 0.38703, test time: 1.63522
# @1, MAP: 0.58333, NDCG: 0.58333, CLICK: 0.58333
# @3, MAP: 0.66489, NDCG: 0.61038, CLICK: 1.56653
# @5, MAP: 0.65713, NDCG: 0.68088, CLICK: 2.14056
# @7, MAP: 0.65097, NDCG: 0.71079, CLICK: 2.31358
# model save in ./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd0/BasicLLM4Rerank.pt
# epoch: 3, train time: 21.97062, test loss: 0.38439, test time: 1.62723
# @1, MAP: 0.58643, NDCG: 0.58643, CLICK: 0.58643
# @3, MAP: 0.66812, NDCG: 0.61569, CLICK: 1.58132
# @5, MAP: 0.66134, NDCG: 0.68508, CLICK: 2.15103
# @7, MAP: 0.65515, NDCG: 0.71402, CLICK: 2.31691
# model save in ./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd0/BasicLLM4Rerank.pt
# epoch: 4, train time: 21.96785, test loss: 0.38800, test time: 1.62632
# @1, MAP: 0.58671, NDCG: 0.58671, CLICK: 0.58671
# @3, MAP: 0.66774, NDCG: 0.61540, CLICK: 1.58062
# @5, MAP: 0.66057, NDCG: 0.68533, CLICK: 2.15282
# @7, MAP: 0.65473, NDCG: 0.71374, CLICK: 2.31585
# epoch: 5, train time: 21.87094, test loss: 0.39373, test time: 1.63582
# @1, MAP: 0.58609, NDCG: 0.58609, CLICK: 0.58609
# @3, MAP: 0.66611, NDCG: 0.61470, CLICK: 1.58023
# @5, MAP: 0.65996, NDCG: 0.68424, CLICK: 2.15095
# @7, MAP: 0.65411, NDCG: 0.71261, CLICK: 2.31381
# epoch: 6, train time: 21.91652, test loss: 0.40274, test time: 1.62763
# @1, MAP: 0.58288, NDCG: 0.58288, CLICK: 0.58288
# @3, MAP: 0.66258, NDCG: 0.61139, CLICK: 1.57434
# @5, MAP: 0.65692, NDCG: 0.68089, CLICK: 2.14380
# @7, MAP: 0.65123, NDCG: 0.70990, CLICK: 2.31035
# Completed run for BasicLLM4Rerank with bs=256, lr=5e-4, wd=0
# Testing with bs=256, lr=5e-4, wd=1e-4
# max hist len 5
# 202412052103
# parameters Namespace(data_dir='../data/amz/proc_data', save_dir='./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd1e-4', reload_path='', setting_path='', device='cuda', seed=1234, output_dim=1, timestamp='202412052103', epoch_num=50, batch_size=256, lr=0.0005, weight_decay=0.0001, adam_betas='0.9,0.999', adam_epsilon=1e-08, lr_sched='cosine', warmup_ratio=0.0, dropout=0.0, convert_dropout=0.0, grad_norm=0, test=False, patience=3, metric_scope=[1, 3, 5, 7], task='rerank', algo='BasicLLM4Rerank', augment=False, aug_prefix='', convert_type='HEA', max_hist_len=5, embed_dim=32, final_mlp_arch=[200, 80], convert_arch=[128, 32], export_num=2, top_expt_num=4, specific_export_num=6, auxi_loss_weight=0, hidden_size=64, rnn_dp=0.0, n_head=2, ff_dim=128, attn_dp=0.0, temperature=1.0, n_layers=3, max_depth=6, n_estimators=100, feature_mlp_arch=[256, 128, 64], llm_heads=8, llm_layers=6, llm_ff_dim=512, norm_scale=1.0, layer_weight_init=1.0, neighbor_weight_init=1.0)
# Train data size: 320368 Test data size: 35834
# metric scope [1, 3, 5, 7]
# test loss: 0.72100, test time: 1.77085
# @1, MAP: 0.23720, NDCG: 0.23720, CLICK: 0.23720
# @3, MAP: 0.36898, NDCG: 0.27010, CLICK: 0.71795
# @5, MAP: 0.39297, NDCG: 0.34451, CLICK: 1.19066
# @7, MAP: 0.38944, NDCG: 0.42478, CLICK: 1.66515
# /gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/optimization.py:139: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:1581.)
#   exp_avg.mul_(beta1).add_(-beta1 + 1.0, grad)
# epoch: 0, train time: 21.78992, test loss: 0.43044, test time: 1.92447
# @1, MAP: 0.52699, NDCG: 0.52699, CLICK: 0.52699
# @3, MAP: 0.62037, NDCG: 0.55207, CLICK: 1.41907
# @5, MAP: 0.61561, NDCG: 0.62742, CLICK: 1.99908
# @7, MAP: 0.60673, NDCG: 0.67155, CLICK: 2.25693
# model save in ./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd1e-4/BasicLLM4Rerank.pt
# epoch: 1, train time: 21.53369, test loss: 0.39752, test time: 1.65024
# @1, MAP: 0.56592, NDCG: 0.56592, CLICK: 0.56592
# @3, MAP: 0.65163, NDCG: 0.59471, CLICK: 1.53148
# @5, MAP: 0.64575, NDCG: 0.66747, CLICK: 2.11096
# @7, MAP: 0.63888, NDCG: 0.70049, CLICK: 2.30200
# model save in ./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd1e-4/BasicLLM4Rerank.pt
# epoch: 2, train time: 21.82539, test loss: 0.38785, test time: 1.63657
# @1, MAP: 0.58168, NDCG: 0.58168, CLICK: 0.58168
# @3, MAP: 0.66389, NDCG: 0.60937, CLICK: 1.56432
# @5, MAP: 0.65662, NDCG: 0.67979, CLICK: 2.13777
# @7, MAP: 0.65021, NDCG: 0.70991, CLICK: 2.31202
# model save in ./model/amz/rerank/BasicLLM4Rerank/Basic_Emb32_epoch50_bs256_lr5e-4_wd1e-4/BasicLLM4Rerank.pt
# ^C
# Traceback (most recent call last):
#   File "/gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/main_rerank.py", line 262, in <module>
#     train(args)
#   File "/gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/main_rerank.py", line 158, in train
#     optimizer.step()
#   File "/home2/kkms4641/miniconda3/envs/LLM/lib/python3.12/site-packages/torch/optim/lr_scheduler.py", line 130, in wrapper
#     return func.__get__(opt, opt.__class__)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home2/kkms4641/miniconda3/envs/LLM/lib/python3.12/site-packages/torch/optim/optimizer.py", line 484, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/gpfs/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS/optimization.py", line 141, in step
#     denom = exp_avg_sq.sqrt().add_(group["eps"])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
