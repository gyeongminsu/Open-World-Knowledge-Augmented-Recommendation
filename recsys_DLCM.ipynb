# %%
import os

# !nvidia-smi
# Out:
# Wed Dec  4 16:06:54 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.02              Driver Version: 555.42.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               On  |   00000000:4F:00.0 Off |                  Off |
# | 30%   29C    P8             23W /  300W |       2MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # Reranking

# %%
os.chdir("/home2/kkms4641/Open-World-Knowledge-Augmented-Recommendation/RS")
# !python run_rerank_DLCM.py
# Out:
# ---------------bs,lr,wd,epoch, export share/spcf, convert arch ---------- 256 5e-4 50 0 2 5 128,32 DLCM
# max hist len 5
# 202412041606
# ...
